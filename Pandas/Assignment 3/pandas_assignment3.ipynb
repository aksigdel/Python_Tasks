# %% [markdown]
# Import necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Countries Dataset

# %%
df_countries=pd.read_csv('sample_data/countries.csv')
df_countries
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                          0.50        1803.987
# 1                          2.89       11803.431
# 2                          1.90       13913.839
# 3                           NaN             NaN
# ...

# %% [markdown]
# How many countries does the dataframe contain?

# %%
len(df_countries.location.unique())
# Out:
# 210

# %% [markdown]
# Retrieve a list of continents from the dataframe?

# %%
lst=(df_countries.continent.unique()).tolist()
lst
# Out:
# ['Asia', 'Europe', 'Africa', 'North America', 'South America', 'Oceania']

# %% [markdown]
# What is the total population of all the countries listed in this dataset?

# %%
df_countries.population.sum()
# Out:
# 7757980095.0

# %% [markdown]
# What is the overall life expectancy across the world?

# %%
df_countries.life_expectancy.mean()
# Out:
# 73.52985507246377

# %% [markdown]
# Create a dataframe containing 10 countries with the highest population.

# %%
df_10highest_pop=df_countries.sort_values('population',ascending=False).head(10)
df_10highest_pop
# Out:
#           location      continent    population  life_expectancy  \
# 41           China           Asia  1.439324e+09            76.91
# 90           India           Asia  1.380004e+09            69.66
# 199  United States  North America  3.310026e+08            78.86
# 91       Indonesia           Asia  2.735236e+08            71.72
# 145       Pakistan           Asia  2.208923e+08            67.27
# 27          Brazil  South America  2.125594e+08            75.88
# 141        Nigeria         Africa  2.061396e+08            54.69
# 15      Bangladesh           Asia  1.646894e+08            72.59
# 157         Russia         Europe  1.459345e+08            72.58
# 125         Mexico  North America  1.289328e+08            75.05
#
#      hospital_beds_per_thousand  gdp_per_capita
# 41                         4.34       15308.712
# 90                         0.53        6426.674
# 199                        2.77       54225.446
# 91                         1.04       11188.744
# ...

# %% [markdown]
# Add a new column in countries_df to record the overall GDP per country (product of population & per capita GDP).

# %%
df_gdp_countries=df_countries.population*df_countries.gdp_per_capita
df_countries.insert(6,'overall_gdp_per_country',df_gdp_countries,True)
df_countries
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita  overall_gdp_per_country
# 0                          0.50        1803.987             7.022622e+10
# 1                          2.89       11803.431             3.396791e+10
# ...

# %% [markdown]
# Create a dataframe containing 10 countries with the lowest GDP per capita, among the counties with population greater than 100 million.

# %%
value=100000000
df_10lowest_gdpcountry=(df_countries.query('population > @value').sort_values('gdp_per_capita')).head(10)
df_10lowest_gdpcountry
# Out:
#         location      continent    population  life_expectancy  \
# 63      Ethiopia         Africa  1.149636e+08            66.60
# 15    Bangladesh           Asia  1.646894e+08            72.59
# 145     Pakistan           Asia  2.208923e+08            67.27
# 141      Nigeria         Africa  2.061396e+08            54.69
# 90         India           Asia  1.380004e+09            69.66
# 151  Philippines           Asia  1.095811e+08            71.23
# 58         Egypt         Africa  1.023344e+08            71.99
# 91     Indonesia           Asia  2.735236e+08            71.72
# 27        Brazil  South America  2.125594e+08            75.88
# 41         China           Asia  1.439324e+09            76.91
#
#      hospital_beds_per_thousand  gdp_per_capita
# 63                         0.30        1729.927
# 15                         0.80        3523.984
# 145                        0.60        5034.708
# 141                         NaN        5338.454
# ...

# %% [markdown]
# Create a data frame that counts the number of countries in each continent?

# %%
df_countries.groupby('continent').location.count()
# Out:
# continent
# Africa           55
# Asia             47
# Europe           51
# North America    36
# Oceania           8
# South America    13
# Name: location, dtype: int64

# %% [markdown]
# Create a data frame showing the total population of each continent.

# %%
df_countries.groupby('continent').population.sum()
# Out:
# continent
# Africa           1.339424e+09
# Asia             4.607388e+09
# Europe           7.485062e+08
# North America    5.912425e+08
# Oceania          4.095832e+07
# South America    4.304611e+08
# Name: population, dtype: float64

# %% [markdown]
# Covid Countries Dataset

# %%
df_covid_countries=pd.read_csv('sample_data/covid-countries-data.csv')
df_covid_countries
# Out:
#            location  total_cases  total_deaths  total_tests
# 0       Afghanistan      38243.0        1409.0          NaN
# 1           Albania       9728.0         296.0          NaN
# 2           Algeria      45158.0        1525.0          NaN
# 3           Andorra       1199.0          53.0          NaN
# 4            Angola       2729.0         109.0          NaN
# ..              ...          ...           ...          ...
# 207  Western Sahara        766.0           1.0          NaN
# 208           World   26059065.0      863535.0          NaN
# 209           Yemen       1976.0         571.0          NaN
# 210          Zambia      12415.0         292.0          NaN
# 211        Zimbabwe       6638.0         206.0      97272.0
#
# [212 rows x 4 columns]

# %% [markdown]
# Count the number of countries for which the total_tests data is missing.

# %%
df_covid_countries.total_tests.isna().sum()
# Out:
# 122

# %% [markdown]
# Merge countries_df with covid_data_df on the location column as combined_df.

# %%
df_combined=df_countries.merge(df_covid_countries, on='location')
df_combined
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita  total_cases  total_deaths  \
# 0                          0.50        1803.987      38243.0        1409.0
# 1                          2.89       11803.431       9728.0         296.0
# ...

# %% [markdown]
# Add columns tests_per_million, cases_per_million and deaths_per_million into combined_df.

# %%
df_combined.insert(9,'tests_per_million', df_combined.total_tests/1000000,True)

# %%
df_combined.insert(9,'cases_per_million', df_combined.total_cases/1000000,True)
df_combined.insert(9,'deaths_per_million', df_combined.total_deaths/1000000,True)

# %% [markdown]
# inserting diff col at same loc shifts prev col

# %%
df_combined
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita  total_cases  total_deaths  \
# 0                          0.50        1803.987      38243.0        1409.0
# 1                          2.89       11803.431       9728.0         296.0
# ...

# %% [markdown]
# Create a dataframe with 10 countries that have the highest number of tests per million people.

# %%
(df_combined.sort_values('tests_per_million',ascending=False).head(10))[['location','tests_per_million']]
# Out:
#                  location  tests_per_million
# 199         United States          83.898416
# 90                  India          44.337201
# 157                Russia          37.176827
# 198        United Kingdom          13.447568
# 73                Germany          11.208091
# 193                Turkey           7.247935
# 197  United Arab Emirates           7.177430
# 177                 Spain           6.416533
# 10              Australia           6.255797
# 35                 Canada           5.545473

# %% [markdown]
# Create a dataframe with 10 countries that have the highest number of positive cases per million people.

# %%
(df_combined.sort_values('cases_per_million',ascending=False).head(10))[['location','cases_per_million']]
# Out:
#           location  cases_per_million
# 199  United States           6.114406
# 27          Brazil           3.997865
# 90           India           3.853406
# 157         Russia           1.005000
# 150           Peru           0.663437
# 42        Colombia           0.633339
# 174   South Africa           0.630595
# 125         Mexico           0.610957
# 177          Spain           0.479554
# 7        Argentina           0.428226

# %% [markdown]
# Create a dataframe with 10 countries that have the highest number of deaths cases per million people?

# %%
(df_combined.sort_values('deaths_per_million',ascending=False).head(10))[['location','deaths_per_million']]
# Out:
#            location  deaths_per_million
# 199   United States            0.185744
# 27           Brazil            0.123780
# 90            India            0.067376
# 125          Mexico            0.065816
# 198  United Kingdom            0.041514
# 97            Italy            0.035497
# 68           France            0.030686
# 150            Peru            0.029259
# 177           Spain            0.029194
# 92             Iran            0.021797
